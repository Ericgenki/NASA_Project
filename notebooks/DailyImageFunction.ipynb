# %%
##for TXLA

from satpy import Scene, find_files_and_readers
from pyresample import create_area_def
from satpy.writers import get_enhanced_image
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
from glob import glob
from satpy import MultiScene

def TXLAfigure(monthyear):
    
    i=0
    base = '/home/hboi-ouri/Projects/RS_Files/TXLADailies/' + monthyear + '/MYD021KM.'

    #files to be used
    filenames = glob('/home/hboi-ouri/Projects/RS_Files/TXLADailies/' + monthyear + '/MYD021KM.*')
    swats = np.unique([f.split('.')[1] for f in filenames])
    
    #area in the figure
    extent = [-94, 27.5, -88, 30.5]
    my_area = create_area_def('my_area', {'proj': 'lcc', 'lon_0': -91., 'lat_0': 29.5, 'lat_1': 29.5, 'lat_2': 29.5},
                width=1500, height=750,
                area_extent=extent, units='degrees')    
        
    fig =  plt.figure(figsize=(6, 4), dpi=400)

    #loop
    for swat in swats:
        dayfiles = glob(base+swat+'*')
        scn = Scene(dayfiles, reader='modis_l1b')
        scn.load(['true_color'])

        #reproject
        new_scn = scn.resample(my_area)

        #generate RGB from true color
        rgb = get_enhanced_image(new_scn['true_color'])

        #extract projection and lon lat from products
        crs = new_scn['true_color'].attrs['area'].to_cartopy_crs()
        lons, lats = new_scn['true_color'].attrs['area'].get_lonlats()

        #true color
        ax1 = plt.subplot(projection=crs)
        rgb.data.plot.imshow(rgb='bands', transform=crs, ax=ax1)
        
        #title & save
        ax1.set_title('MODISA_Mdelta_%s' % new_scn.start_time.isoformat())
        fig.savefig('/home/hboi-ouri/Projects/NASA_Project/outputs/DailyImages/TXLA/MODISA_Mdelta_%s_rgb.jpeg' % new_scn.start_time.isoformat())

# %%
TXLAfigure('June2022')
# Out:
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 TXLAfigure('June2022')
#
# Input In [1], in TXLAfigure(monthyear)
#      45 #true color
#      46 ax1 = plt.subplot(projection=crs)
# ---> 47 rgb.data.plot.imshow(rgb='bands', transform=crs, ax=ax1)
#      49 #title & save
#      50 ax1.set_title('MODISA_Mdelta_%s' % new_scn.start_time.isoformat())
#
# File ~/anaconda3/envs/satpy/lib/python3.8/site-packages/xarray/plot/plot.py:1302, in _plot2d.<locals>.plotmethod(_PlotMethods_obj, x, y, figsize, size, aspect, ax, row, col, col_wrap, xincrease, yincrease, add_colorbar, add_labels, vmin, vmax, cmap, colors, center, robust, extend, levels, infer_intervals, subplot_kws, cbar_ax, cbar_kwargs, xscale, yscale, xticks, yticks, xlim, ylim, norm, **kwargs)
#    1300 for arg in ["_PlotMethods_obj", "newplotfunc", "kwargs"]:
#    1301     del allargs[arg]
# -> 1302 return newplotfunc(**allargs)
#
# File ~/anaconda3/envs/satpy/lib/python3.8/site-packages/xarray/plot/plot.py:1204, in _plot2d.<locals>.newplotfunc(darray, x, y, figsize, size, aspect, ax, row, col, col_wrap, xincrease, yincrease, add_colorbar, add_labels, vmin, vmax, cmap, center, robust, extend, levels, infer_intervals, colors, subplot_kws, cbar_ax, cbar_kwargs, xscale, yscale, xticks, yticks, xlim, ylim, norm, **kwargs)
#    1200     raise ValueError("plt.imshow's `aspect` kwarg is not available in xarray")
#    1202 ax = get_axis(figsize, size, aspect, ax, **subplot_kws)
# -> 1204 primitive = plotfunc(
#    1205     xplt,
#    1206     yplt,
#    1207     zval,
#    1208     ax=ax,
#    1209     cmap=cmap_params["cmap"],
#    1210     vmin=cmap_params["vmin"],
#    1211     vmax=cmap_params["vmax"],
#    1212     norm=cmap_params["norm"],
#    1213     **kwargs,
#    1214 )
#    1216 # Label the plot with metadata
#    1217 if add_labels:
#
# File ~/anaconda3/envs/satpy/lib/python3.8/site-packages/xarray/plot/plot.py:1388, in imshow(x, y, z, ax, **kwargs)
#    1386     else:
#    1387         z = z.copy()
# -> 1388     z[np.any(z.mask, axis=-1), -1] = 0
#    1390 primitive = ax.imshow(z, **defaults)
#    1392 # If x or y are strings the ticklabels have been replaced with
#    1393 # integer indices. Replace them back to strings:
#
# File <__array_function__ internals>:5, in any(*args, **kwargs)
#
# File ~/anaconda3/envs/satpy/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2358, in any(a, axis, out, keepdims, where)
#    2268 @array_function_dispatch(_any_dispatcher)
#    2269 def any(a, axis=None, out=None, keepdims=np._NoValue, *, where=np._NoValue):
#    2270     """
#    2271     Test whether any array element along a given axis evaluates to True.
#    2272
#    (...)
#    2356
#    2357     """
# -> 2358     return _wrapreduction(a, np.logical_or, 'any', axis, None, out,
#    2359                           keepdims=keepdims, where=where)
#
# File ~/anaconda3/envs/satpy/lib/python3.8/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
## For FLBay

from satpy import Scene, find_files_and_readers
from pyresample import create_area_def
from satpy.writers import get_enhanced_image
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
from glob import glob
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from satpy import MultiScene
from satpy.multiscene import timeseries

def FLBayfigure(monthyear):
    
    i=0
    base = '/home/hboi-ouri/Projects/RS_Files/FLBayDailies/' + monthyear + '/MYD021KM.'

    #files to be used
    filenames = glob('/home/hboi-ouri/Projects/RS_Files/FLBayDailies/' + monthyear + '/MYD021KM.*')
    swats = np.unique([f.split('.')[1] for f in filenames])
    

    #area in the figure
    extent = [-82.0, 24.4, -80.0, 25.6]
    my_area = create_area_def('my_area', {'proj': 'lcc', 'lon_0': -81.0, 'lat_0': 25.0, 'lat_1': 25.0, 'lat_2': 25.0},
                    width=1500, height=750,
                    area_extent=extent, units='degrees')
        
    fig =  plt.figure(figsize=(6, 4), dpi=400)

    #loop
    for swat in swats:
        dayfiles = glob(base+swat+'*')
        scn = Scene(dayfiles, reader='modis_l1b')
        scn.load(['true_color'])

        #reproject
        new_scn = scn.resample(my_area)

        #generate RGB from true color
        rgb = get_enhanced_image(new_scn['true_color'])

        #extract projection and lon lat from products
        crs = new_scn['true_color'].attrs['area'].to_cartopy_crs()
        lons, lats = new_scn['true_color'].attrs['area'].get_lonlats()

        #left true color
        ax1 = plt.subplot(projection=crs)
        rgb.data.plot.imshow(rgb='bands', transform=crs, ax=ax1)

        #title & save
        ax1.set_title('MODISA_FLBay_%s' % new_scn.start_time.isoformat())
        fig.savefig('/home/hboi-ouri/Projects/NASA_Project/outputs/DailyImages/FLBay/FLBay%s_rgb.png' % new_scn.start_time.isoformat())

# %%
FLBayfigure('June2022')
# Out:
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in arccos
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/anaconda3/envs/satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:485: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from satpy import Scene, find_files_and_readers
from pyresample import create_area_def
from satpy.writers import get_enhanced_image
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
from glob import glob
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from satpy import MultiScene
from satpy.multiscene import timeseries

def TXLAfigure(monthyear):
    
    i=0
    base = '/home/hboi-ouri/Projects/RS_Files/TXLADailies/' + monthyear + '/MYD021KM.'

    filenames = glob('/home/hboi-ouri/Projects/RS_Files/TXLADailies/' + monthyear + '/MYD021KM.*')
    swats = np.unique([f.split('.')[1] for f in filenames])
    
    extent = [-94, 27.5, -88, 30.5]
    my_area = create_area_def('my_area', {'proj': 'lcc', 'lon_0': -91., 'lat_0': 29.5, 'lat_1': 29.5, 'lat_2': 29.5},
                width=1500, height=750,
                area_extent=extent, units='degrees')    
        
    fig =  plt.figure(figsize=(6, 4), dpi=400)

    for swat in swats:
        dayfiles = glob(base+swat+'*')
        scn = Scene(dayfiles, reader='modis_l1b')
        scn.load(['true_color'])

        new_scn = scn.resample(my_area)

        rgb = get_enhanced_image(new_scn['true_color'])

        crs = new_scn['true_color'].attrs['area'].to_cartopy_crs()
        lons, lats = new_scn['true_color'].attrs['area'].get_lonlats()

        ax1 = plt.subplot(projection=crs)
        rgb.data.plot.imshow(rgb='bands', transform=crs, ax=ax1)
        
        ax1.set_title('MODISA_Mdelta_%s' % new_scn.start_time.isoformat())
        fig.savefig('/home/hboi-ouri/Projects/NASA_Project/outputs/DailyImages/TXLA/MODISA_Mdelta_%s_rgb.png' % new_scn.start_time.isoformat())
