# %%
##for TXLA

from satpy import Scene, find_files_and_readers
from pyresample import create_area_def
from satpy.writers import get_enhanced_image
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
from glob import glob
from satpy import MultiScene

def MODIS(monthyear):
    
    i=0
    base = '/home/hboi-ouri/Projects/RS_Files/MODIS2010-2012/' + monthyear + '/AQUA_MODIS.'

    #files to be used
    filenames = glob('/home/hboi-ouri/Projects/RS_Files/MODIS2010-2012/' + monthyear + '/AQUA_MODIS.*')
    swats = np.unique([f.split('.')[1] for f in filenames])
    
    #area in the figure
    extent = [-94, 27.5, -88, 30.5]
    my_area = create_area_def('my_area', {'proj': 'lcc', 'lon_0': -91., 'lat_0': 29.5, 'lat_1': 29.5, 'lat_2': 29.5},
                width=1500, height=750,
                area_extent=extent, units='degrees')    
        
    fig =  plt.figure(figsize=(6, 4), dpi=400)

    #loop
    for swat in swats:
        dayfiles = glob(base+swat+'*')
        scn = Scene(dayfiles, reader='modis_l1b')
        scn.load(['true_color'])

        #reproject
        new_scn = scn.resample(my_area)

        #generate RGB from true color
        rgb = get_enhanced_image(new_scn['true_color'])

        #extract projection and lon lat from products
        crs = new_scn['true_color'].attrs['area'].to_cartopy_crs()
        lons, lats = new_scn['true_color'].attrs['area'].get_lonlats()

        #true color
        ax1 = plt.subplot(projection=crs)
        rgb.data.plot.imshow(rgb='bands', transform=crs, ax=ax1)
        
        #title & save
        ax1.set_title('MODISA_Mdelta_%s' % new_scn.start_time.isoformat())
        fig.savefig('/home/hboi-ouri/Projects/NASA_Project/outputs/DailyImages/TXLA/MODISA_Mdelta_%s_rgb.png' % new_scn.start_time.isoformat())
        fig.clear()

# %%
##for TXLA

from satpy import Scene, find_files_and_readers
from pyresample import create_area_def
from satpy.writers import get_enhanced_image
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
from glob import glob
from satpy import MultiScene

def MODIS(monthyear):
    
    i=0
    base = '/home/hboi-ouri/Projects/RS_Files/MODIS2010-2012/' + monthyear + '/AQUA_MODIS.'

    #files to be used
    filenames = glob('/home/hboi-ouri/Projects/RS_Files/MODIS2010-2012/' + monthyear + '/AQUA_MODIS.*')
    swats = np.unique([f.split('.')[1] for f in filenames])
    
    #area in the figure
    extent = [-94, 27.5, -88, 30.5]
    my_area = create_area_def('my_area', {'proj': 'lcc', 'lon_0': -91., 'lat_0': 29.5, 'lat_1': 29.5, 'lat_2': 29.5},
                width=1500, height=750,
                area_extent=extent, units='degrees')    
        
    fig =  plt.figure(figsize=(6, 4), dpi=400)

    #loop
    for swat in swats:
        dayfiles = glob(base+swat+'*')
        scn = Scene(dayfiles, reader='modis_l1b')
        scn.keys()
        scn.available_dataset_names()

# %%
MODIS('SEP2012')
# Out:
# No filenames found for reader: modis_l1b
# Don't know how to open the following files: {'/home/hboi-ouri/Projects/RS_Files/MODIS2010-2012/SEP2012/AQUA_MODIS.20120901T191501.L2.OC.x.nc'}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 MODIS('SEP2012')
#
# Input In [4], in MODIS(monthyear)
#      30 for swat in swats:
#      31     dayfiles = glob(base+swat+'*')
# ---> 32     scn = Scene(dayfiles, reader='modis_l1b')
#      33     scn.keys()
#      34     scn.available_dataset_names()
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/scene.py:133, in Scene.__init__(self, filenames, reader, filter_parameters, reader_kwargs)
#     130 if filenames:
#     131     filenames = convert_remote_files_to_fsspec(filenames, storage_options)
# --> 133 self._readers = self._create_reader_instances(filenames=filenames,
#     134                                               reader=reader,
#     135                                               reader_kwargs=cleaned_reader_kwargs)
#     136 self._datasets = DatasetDict()
#     137 self._wishlist = set()
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/scene.py:154, in Scene._create_reader_instances(self, filenames, reader, reader_kwargs)
#     149 def _create_reader_instances(self,
#     150                              filenames=None,
#     151                              reader=None,
#     152                              reader_kwargs=None):
#     153     """Find readers and return their instances."""
# --> 154     return load_readers(filenames=filenames,
#     155                         reader=reader,
#     156                         reader_kwargs=reader_kwargs)
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/readers/__init__.py:581, in load_readers(filenames, reader, reader_kwargs)
#     578         break
#     580 _check_remaining_files(remaining_filenames)
# --> 581 _check_reader_instances(reader_instances)
#     582 return reader_instances
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/readers/__init__.py:620, in _check_reader_instances(reader_instances)
#     618 def _check_reader_instances(reader_instances):
#     619     if not reader_instances:
# --> 620         raise ValueError("No supported files found")
#     621     if not any(list(r.available_dataset_ids) for r in reader_instances.values()):
#     622         raise ValueError("No dataset could be loaded. Either missing "
#     623                          "requirements (such as Epilog, Prolog) or none of the "
#     624                          "provided files match the filter parameters.")
#
# ValueError: No supported files found

# %%
## For FLBay

from satpy import Scene, find_files_and_readers
from pyresample import create_area_def
from satpy.writers import get_enhanced_image
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
from glob import glob
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from satpy import MultiScene
from satpy.multiscene import timeseries

def FLBayfigure(monthyear):
    
    i=0
    base = '/home/hboi-ouri/Projects/RS_Files/FLBayDailies/' + monthyear + '/MYD021KM.'

    #files to be used
    filenames = glob('/home/hboi-ouri/Projects/RS_Files/FLBayDailies/' + monthyear + '/MYD021KM.*')
    swats = np.unique([f.split('.')[1] for f in filenames])
    

    #area in the figure
    extent = [-82.0, 24.4, -80.0, 25.6]
    my_area = create_area_def('my_area', {'proj': 'lcc', 'lon_0': -81.0, 'lat_0': 25.0, 'lat_1': 25.0, 'lat_2': 25.0},
                    width=1500, height=750,
                    area_extent=extent, units='degrees')
        
    fig =  plt.figure(figsize=(6, 4), dpi=400)

    #loop
    for swat in swats:
        dayfiles = glob(base+swat+'*')
        scn = Scene(dayfiles, reader='modis_l1b')
        scn.load(['true_color'])

        #reproject
        new_scn = scn.resample(my_area)

        #generate RGB from true color
        rgb = get_enhanced_image(new_scn['true_color'])

        #extract projection and lon lat from products
        crs = new_scn['true_color'].attrs['area'].to_cartopy_crs()
        lons, lats = new_scn['true_color'].attrs['area'].get_lonlats()

        #left true color
        ax1 = plt.subplot(projection=crs)
        rgb.data.plot.imshow(rgb='bands', transform=crs, ax=ax1)

        #title & save
        ax1.set_title('MODISA_FLBay_%s' % new_scn.start_time.isoformat())
        fig.savefig('/home/hboi-ouri/Projects/NASA_Project/outputs/DailyImages/FLBay/FLBay%s_rgb.png' % new_scn.start_time.isoformat())
        fig.clear()

# %%
FLBayfigure('July2022')
FLBayfigure('August2022')
FLBayfigure('September2022')
# Out:
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/geotiepoints/geointerpolator.py:89: RuntimeWarning: invalid value encountered in arccos
#   lat_z_only = 90 - np.rad2deg(np.arccos(z__ / radius))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)

# %%
from satpy import Scene, find_files_and_readers
from pyresample import create_area_def
from satpy.writers import get_enhanced_image
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
from glob import glob
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from satpy import MultiScene
from satpy.multiscene import timeseries

def TXLAfigure(monthyear):
    
    i=0
    base = '/home/hboi-ouri/Projects/RS_Files/TXLADailies/' + monthyear + '/MYD021KM.'

    filenames = glob('/home/hboi-ouri/Projects/RS_Files/TXLADailies/' + monthyear + '/MYD021KM.*')
    swats = np.unique([f.split('.')[1] for f in filenames])
    
    extent = [-94, 27.5, -88, 30.5]
    my_area = create_area_def('my_area', {'proj': 'lcc', 'lon_0': -91., 'lat_0': 29.5, 'lat_1': 29.5, 'lat_2': 29.5},
                width=1500, height=750,
                area_extent=extent, units='degrees')    
        
    fig =  plt.figure(figsize=(6, 4), dpi=400)

    for swat in swats:
        dayfiles = glob(base+swat+'*')
        scn = Scene(dayfiles, reader='modis_l1b')
        scn.load(['true_color'])

        new_scn = scn.resample(my_area)

        rgb = get_enhanced_image(new_scn['true_color'])

        crs = new_scn['true_color'].attrs['area'].to_cartopy_crs()
        lons, lats = new_scn['true_color'].attrs['area'].get_lonlats()

        ax1 = plt.subplot(projection=crs)
        rgb.data.plot.imshow(rgb='bands', transform=crs, ax=ax1)
        
        ax1.set_title('MODISA_Mdelta_%s' % new_scn.start_time.isoformat())
        fig.savefig('/home/hboi-ouri/Projects/NASA_Project/outputs/DailyImages/TXLA/MODISA_Mdelta_%s_rgb.png' % new_scn.start_time.isoformat())

# %%
from satpy import Scene, find_files_and_readers
from pyresample import create_area_def
from satpy.writers import get_enhanced_image
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
from glob import glob
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from satpy import MultiScene
from satpy.multiscene import timeseries

def combinedplot():

    base = '/home/hboi-ouri/Projects/NASA_Project/outputs/CombinedNC/MODIS/'
    
    filenames = glob('/home/hboi-ouri/Projects/NASA_Project/outputs/CombinedNC/MODIS/*')

    
    extent = [-94, 27.5, -88, 30.5]
    my_area = create_area_def('my_area', {'proj': 'lcc', 'lon_0': -91., 'lat_0': 29.5, 'lat_1': 29.5, 'lat_2': 29.5},
                width=1500, height=750,
                area_extent=extent, units='degrees')    
        
    fig =  plt.figure(figsize=(6, 4), dpi=400)

    for file in filenames:
        dayfiles = glob(base+'*')
        scn = Scene(dayfiles, reader='modis_l1b')
        scn.load(['true_color'])

        new_scn = scn.resample(my_area)

        rgb = get_enhanced_image(new_scn['true_color'])

        crs = new_scn['true_color'].attrs['area'].to_cartopy_crs()
        lons, lats = new_scn['true_color'].attrs['area'].get_lonlats()

        ax1 = plt.subplot(projection=crs)
        rgb.data.plot.imshow(rgb='bands', transform=crs, ax=ax1)
        
        date = [f.split('.')[1] for f in files]
        year = ((date[1])[0:4])
        month = ((date[1])[4:6])
        
        ax1.set_title('MODISA_Mdelta_Combined_' + year + '_' + month)
        fig.savefig('/home/hboi-ouri/Projects/NASA_Project/outputs/CombinedNC/MODISFigures/CombinedMODISA' + year + '_' + month + '.png')

# %%
combinedplot()
# Out:
# No filenames found for reader: modis_l1b
# Don't know how to open the following files: {'/home/hboi-ouri/Projects/NASA_Project/outputs/CombinedNC/MODIS/2010_08_MODIS_L2.nc', '/home/hboi-ouri/Projects/NASA_Project/outputs/CombinedNC/MODIS/2012_09_MODIS_L2.nc', '/home/hboi-ouri/Projects/NASA_Project/outputs/CombinedNC/MODIS/2010_07_MODIS_L2.nc'}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 combinedplot()
#
# Input In [14], in combinedplot()
#      27 for file in filenames:
#      28     dayfiles = glob(base+'*')
# ---> 29     scn = Scene(dayfiles, reader='modis_l1b')
#      30     scn.load(['true_color'])
#      32     new_scn = scn.resample(my_area)
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/scene.py:133, in Scene.__init__(self, filenames, reader, filter_parameters, reader_kwargs)
#     130 if filenames:
#     131     filenames = convert_remote_files_to_fsspec(filenames, storage_options)
# --> 133 self._readers = self._create_reader_instances(filenames=filenames,
#     134                                               reader=reader,
#     135                                               reader_kwargs=cleaned_reader_kwargs)
#     136 self._datasets = DatasetDict()
#     137 self._wishlist = set()
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/scene.py:154, in Scene._create_reader_instances(self, filenames, reader, reader_kwargs)
#     149 def _create_reader_instances(self,
#     150                              filenames=None,
#     151                              reader=None,
#     152                              reader_kwargs=None):
#     153     """Find readers and return their instances."""
# --> 154     return load_readers(filenames=filenames,
#     155                         reader=reader,
#     156                         reader_kwargs=reader_kwargs)
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/readers/__init__.py:581, in load_readers(filenames, reader, reader_kwargs)
#     578         break
#     580 _check_remaining_files(remaining_filenames)
# --> 581 _check_reader_instances(reader_instances)
#     582 return reader_instances
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/readers/__init__.py:620, in _check_reader_instances(reader_instances)
#     618 def _check_reader_instances(reader_instances):
#     619     if not reader_instances:
# --> 620         raise ValueError("No supported files found")
#     621     if not any(list(r.available_dataset_ids) for r in reader_instances.values()):
#     622         raise ValueError("No dataset could be loaded. Either missing "
#     623                          "requirements (such as Epilog, Prolog) or none of the "
#     624                          "provided files match the filter parameters.")
#
# ValueError: No supported files found
