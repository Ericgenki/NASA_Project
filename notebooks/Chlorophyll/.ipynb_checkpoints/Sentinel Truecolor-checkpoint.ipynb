# %%
## For FLBay

from satpy import Scene, find_files_and_readers
from pyresample import create_area_def
from satpy.writers import get_enhanced_image
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
from glob import glob
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from satpy import MultiScene
from satpy import available_readers
from satpy.multiscene import timeseries
from skimage import exposure

import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from mpl_toolkits.axes_grid1 import AxesGrid, make_axes_locatable
from glob import glob
import xarray as xr
import pandas as pd
import numpy as np1
from pyresample import geometry, create_area_def
from satpy import Scene
from cartopy.mpl.geoaxes import GeoAxes
import cmocean
import cmocean.cm as cmo
import matplotlib.cm as cm
from matplotlib import ticker

# %%
olci_dir = '/home/hboi-ouri/Projects/RS_Files/Chlorophyll/FLBay_Hanna/Sentinel Truecolor/'
olci_xr_mf = xr.open_mfdataset(olci_dir+'*_radiance.nc', combine='by_coords')
olci_geo_coords = xr.open_dataset(olci_dir+'geo_coordinates.nc')
lat = olci_geo_coords.latitude.data
lon = olci_geo_coords.longitude.data



def select_channels_for_rgb(xarray, red_channel, green_channel, blue_channel):
    """ 
    Selects the channels / bands of a multi-dimensional xarray for red, green and blue composites.
    
    Parameters:
        xarray(xarray Dataset): xarray Dataset object that stores the different channels / bands.
        red_channel(str): Name of red channel to be selected
        green_channel(str): Name of green channel to be selected
        blue_channel(str): Name of blue channel to be selected

    Returns:
        Three xarray DataArray objects with selected channels / bands
    """  
    return xarray[red_channel], xarray[green_channel], xarray[blue_channel]
red, green, blue = select_channels_for_rgb(olci_xr_mf, 'Oa08_radiance', 'Oa06_radiance', 'Oa04_radiance')

def normalize(array):
    """ 
    Normalizes a numpy array / xarray DataArray object value to values between 0 and 1.
    
    Parameters:
        xarray(numpy array or xarray DataArray): xarray DataArray or numpy array object.

    Returns:
        Normalized array
    """ 
    array_min, array_max = array.min(), array.max()
    return ((array - array_min)/(array_max - array_min))

redn = normalize(red)
greenn = normalize(green)
bluen = normalize(blue)

rgb = np.dstack((redn, greenn, bluen))

mesh_rgb = rgb[:, :, :]
colorTuple = mesh_rgb.reshape((mesh_rgb.shape[0] * mesh_rgb.shape[1]), 3)
colorTuple = np.insert(colorTuple, 3, 1.0, axis=1)

def visualize_s3_pcolormesh(color_array, array, latitude, longitude, title):
    """ 
    Visualizes a numpy array (Sentinel-3 data) with matplotlib's 'pcolormesh' function as composite.
    
    Parameters:
        color_array (numpy MaskedArray): any numpy MaskedArray, e.g. loaded with the NetCDF library and the Dataset function
        longitude (numpy Array): array with longitude values
        latitude (numpy Array) : array with latitude values
        title (str): title of the resulting plot
    """
    fig=plt.figure(figsize=(20, 12))

    ax=plt.axes(projection=ccrs.Mercator())
    ax.coastlines()
    ax.set_extent([-79.9,-82.1, 25.7, 24.3]) # Mediterranean
    

#     gl = ax.gridlines(draw_labels=True, linestyle='--')
#     gl.xlabels_top=False
#     gl.ylabels_right=False
#     gl.xformatter=LONGITUDE_FORMATTER
#     gl.yformatter=LATITUDE_FORMATTER
#     gl.xlabel_style={'size':14}
#     gl.ylabel_style={'size':14}
    
    img1 = plt.pcolormesh(longitude, latitude, array*np.nan, color=colorTuple,
                          clip_on = True,
                          edgecolors=None,
                          zorder=0,
                          transform=ccrs.PlateCarree()
                          )
    ax.set_title(title, fontsize=20, pad=20.0)
    plt.show()

# %%
visualize_s3_pcolormesh(color_array=colorTuple,
                        array=red, 
                        latitude=lat, 
                        longitude=lon, 
                        title='Sentinel-3 OLCI Level-1 True Colour - "26 March 2023"')
# Out:
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py:1785: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   result = super().pcolormesh(*args, **kwargs)

# %%
##for TXLA

from satpy import Scene, find_files_and_readers
from pyresample import create_area_def
from satpy.writers import get_enhanced_image
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
from glob import glob
from satpy import MultiScene


def TXLAfigure(monthyear):
    
    #files to be used
    filenames = glob('/home/hboi-ouri/Projects/RS_Files/Chlorophyll/FLBay_Hanna/Sentinel Truecolor/*')
    
    #area in the figure
    extent = [-81.25, -80.75, 25.5, 24.75]
    my_area = create_area_def('my_area', {'proj': 'lcc', 'lon_0': -81, 'lat_0': 25.125, 
                                          'lat_1': 25.125, 'lat_2': 25.125},
                width=1500, height=750,
                area_extent=extent, units='degrees')    
        
    fig =  plt.figure(figsize=(6, 4), dpi=400)

    #loop
    for swat in swats:
        scn = Scene(filenames, reader='olci_l1b')
        scn.load(['true_color'])

        #reproject
        new_scn = scn.resample(my_area)

        #generate RGB from true color
        rgb = get_enhanced_image(new_scn['true_color'])

        #extract projection and lon lat from products
        crs = new_scn['true_color'].attrs['area'].to_cartopy_crs()
        lons, lats = new_scn['true_color'].attrs['area'].get_lonlats()

        #true color
        ax1 = plt.subplot(projection=crs)
        rgb.data.plot.imshow(rgb='bands', transform=crs, ax=ax1)

        
        #title & save
        ax1.set_title('MODISA_Mdelta_%s' % new_scn.start_time.isoformat())
        fig.savefig('/home/hboi-ouri/Projects/NASA_ProjectExp/outputs/DailyImages/TXLA/MODISA_Mdelta_%s_rgb.png' % new_scn.start_time.isoformat())
        fig.clear()

# %%
files = find_files_and_readers(sensor='olci',

                               base_dir="/home/hboi-ouri/Projects/RS_Files/Chlorophyll/FLBay_Hanna/Sentinel Truecolor/",
                               reader='olci_l1b')
 
scn = Scene(filenames=files)
scn.load(['true_color'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 files = find_files_and_readers(sensor='olci',
#       2
#       3                                base_dir="/home/hboi-ouri/Projects/RS_Files/Chlorophyll/FLBay_Hanna/Sentinel Truecolor/",
#       4                                reader='olci_l2')
#       6 scn = Scene(filenames=files)
#       7 scn.load(['true_color'])
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/readers/__init__.py:486, in find_files_and_readers(start_time, end_time, base_dir, reader, sensor, filter_parameters, reader_kwargs, missing_ok, fs)
#     483     raise ValueError("Sensor '{}' not supported by any readers".format(sensor))
#     485 if not (reader_files or missing_ok):
# --> 486     raise ValueError("No supported files found")
#     487 return reader_files
#
# ValueError: No supported files found

# %%
sorted(available_readers())
# Out:
# ['abi_l1b',
#  'abi_l1b_scmi',
#  'abi_l2_nc',
#  'acspo',
#  'agri_l1',
#  'ahi_hrit',
#  'ahi_hsd',
#  'ahi_l1b_gridded_bin',
#  'ami_l1b',
#  'amsr2_l1b',
#  'amsr2_l2',
#  'amsr2_l2_gaasp',
#  'amsub_l1c_aapp',
#  'ascat_l2_soilmoisture_bufr',
#  'avhrr_l1b_aapp',
#  'avhrr_l1b_eps',
#  'avhrr_l1b_hrpt',
#  'avhrr_l1c_eum_gac_fdr_nc',
#  'clavrx',
#  'cmsaf-claas2_l2_nc',
#  'electrol_hrit',
#  'fci_l1c_nc',
#  'fci_l2_nc',
#  'generic_image',
#  'geocat',
#  'ghrsst_l2',
#  'glm_l2',
#  'goes-imager_hrit',
#  'goes-imager_nc',
#  'gpm_imerg',
#  'hy2_scat_l2b_h5',
#  'iasi_l2',
#  'iasi_l2_so2_bufr',
#  'jami_hrit',
#  'maia',
#  'mersi2_l1b',
#  'mhs_l1c_aapp',
#  'mimicTPW2_comp',
#  'mirs',
#  'modis_l1b',
#  'modis_l2',
#  'msu_gsa_l1b',
#  'mtsat2-imager_hrit',
#  'mviri_l1b_fiduceo_nc',
#  'nucaps',
#  'nwcsaf-geo',
#  'nwcsaf-msg2013-hdf5',
#  'nwcsaf-pps_nc',
#  'oceancolorcci_l3_nc',
#  'olci_l1b',
#  'olci_l2',
#  'omps_edr',
#  'safe_sar_l2_ocn',
#  'satpy_cf_nc',
#  'seadas_l2',
#  'seviri_l1b_hrit',
#  'seviri_l1b_icare',
#  'seviri_l1b_native',
#  'seviri_l1b_nc',
#  'seviri_l2_bufr',
#  'seviri_l2_grib',
#  'slstr_l1b',
#  'smos_l2_wind',
#  'tropomi_l2',
#  'vaisala_gld360',
#  'vii_l1b_nc',
#  'vii_l2_nc',
#  'viirs_compact',
#  'viirs_edr_active_fires',
#  'viirs_edr_flood',
#  'viirs_l1b',
#  'viirs_sdr',
#  'virr_l1b']

# %%
from satpy.scene import Scene
from satpy import find_files_and_readers
from datetime import datetime
 
extent = [-81.25, -80.75, 25.5, 24.75]

files = find_files_and_readers(sensor='olci',
                               start_time=datetime(2023, 5, 4, 15, 14),
                               end_time=datetime(2023, 5, 4, 15, 17),
                               base_dir="/home/hboi-ouri/Downloads/S3A_OL_1_EFR____20230504T151442_20230504T151742_20230505T193906_0180_098_239_2520_MAR_O_NT_002.SEN3",
                               reader='olci_l1b')
 
    
my_area = create_area_def('my_area', {'proj': 'lcc', 'lon_0': -81, 'lat_0': 25.125, 
                                      'lat_1': 25.125, 'lat_2': 25.125},
            width=1500, height=750,
            area_extent=extent, units='degrees')    

fig =  plt.figure(figsize=(6, 4), dpi=400)
scn = Scene(filenames=files)
scn.load(['true_color'])

new_scn = scn.resample(my_area)

#generate RGB from true color
rgb = get_enhanced_image(new_scn['true_color'])

crs = new_scn['true_color'].attrs['area'].to_cartopy_crs()
lons, lats = new_scn['true_color'].attrs['area'].get_lonlats()

#true color
ax1 = plt.subplot(projection=crs)
rgb.data.plot.imshow(rgb='bands', transform=crs, ax=ax1)
# scn.save_dataset('true_color', filename='/home/hboi-ouri/Downloads/true_color_gnc_tutorial'+'.png')
# Out:
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in log
#   return func(*(_execute_task(a, cache) for a in args))
# /home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/modifiers/angles.py:502: RuntimeWarning: invalid value encountered in log
#   grad_factor = 1. - np.log(grad_factor + 1) / np.log(2)

# %%
files = glob('/home/hboi-ouri/Downloads/S3A_OL_1_EFR____20230504T151442_20230504T151742_20230505T193906_0180_098_239_2520_MAR_O_NT_002.SEN3/S3A_OL_1_EFR____20230504T151442_20230504T151742_20230505T193906_0180_098_239_2520_MAR_O_NT_002.SEN3*')
scn = Scene(filenames=files)

scn.all_dataset_names()
# Out:
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: oceancolorcci_l3_nc
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: ghrsst_l2
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: nwcsaf-geo
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: nucaps
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: abi_l1b_scmi
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: modis_l2
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: gpm_imerg
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: viirs_sdr
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: virr_l1b
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: amsub_l1c_aapp
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: iasi_l2
# INFO:satpy.readers:Cannot use ['/home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/etc/readers/grib.yaml']
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: fci_l1c_nc
# INFO:satpy.readers:Cannot use ['/home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/etc/readers/sar-c_safe.yaml']
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: maia
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: avhrr_l1c_eum_gac_fdr_nc
# INFO:satpy.readers:Cannot use ['/home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/etc/readers/scatsat1_l2b.yaml']
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: safe_sar_l2_ocn
# INFO:satpy.readers:Cannot use ['/home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/etc/readers/msi_safe.yaml']
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: avhrr_l1b_eps
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: avhrr_l1b_aapp
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: mersi2_l1b
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: satpy_cf_nc
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: amsr2_l2_gaasp
# INFO:satpy.readers:Cannot use ['/home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/etc/readers/avhrr_l1b_gaclac.yaml']
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: seviri_l2_bufr
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: clavrx
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: ahi_l1b_gridded_bin
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: viirs_l1b
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: seadas_l2
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: seviri_l1b_hrit
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: slstr_l1b
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: olci_l1b
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: mirs
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: ami_l1b
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: electrol_hrit
# INFO:satpy.readers:Cannot use ['/home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/etc/readers/hsaf_grib.yaml']
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: mhs_l1c_aapp
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: geocat
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: nwcsaf-msg2013-hdf5
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: viirs_compact
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: fci_l2_nc
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: abi_l2_nc
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: amsr2_l2
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: msu_gsa_l1b
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: vii_l2_nc
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: ascat_l2_soilmoisture_bufr
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: goes-imager_hrit
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: jami_hrit
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: viirs_edr_active_fires
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: olci_l2
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: glm_l2
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: mimicTPW2_comp
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: ahi_hrit
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: ahi_hsd
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: omps_edr
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: vaisala_gld360
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: smos_l2_wind
# INFO:satpy.readers:Cannot use ['/home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/etc/readers/slstr_l2.yaml']
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: seviri_l2_grib
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: seviri_l1b_icare
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: generic_image
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: iasi_l2_so2_bufr
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: mtsat2-imager_hrit
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: modis_l1b
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: acspo
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: agri_l1
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: goes-imager_nc
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: seviri_l1b_nc
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: cmsaf-claas2_l2_nc
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: tropomi_l2
# INFO:satpy.readers:Cannot use ['/home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/etc/readers/caliop_l2_cloud.yaml']
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: nwcsaf-pps_nc
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: avhrr_l1b_hrpt
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: vii_l1b_nc
# INFO:satpy.readers:Cannot use ['/home/hboi-ouri/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/etc/readers/li_l2.yaml']
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: amsr2_l1b
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: hy2_scat_l2b_h5
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: seviri_l1b_native
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: mviri_l1b_fiduceo_nc
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: viirs_edr_flood
# WARNING:satpy.readers.yaml_reader:No filenames found for reader: abi_l1b
# WARNING:satpy.readers:Don't know how to open the following files: {'/home/hboi-ouri/Downloads/S3A_OL_1_EFR____20230504T151442_20230504T151742_20230505T193906_0180_098_239_2520_MAR_O_NT_002.SEN3/S3A_OL_1_EFR____20230504T151442_20230504T151742_20230505T193906_0180_098_239_2520_MAR_O_NT_002.SEN3'}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [31], in <cell line: 2>()
#       1 files = glob('/home/hboi-ouri/Downloads/S3A_OL_1_EFR____20230504T151442_20230504T151742_20230505T193906_0180_098_239_2520_MAR_O_NT_002.SEN3/S3A_OL_1_EFR____20230504T151442_20230504T151742_20230505T193906_0180_098_239_2520_MAR_O_NT_002.SEN3*')
# ----> 2 scn = Scene(filenames=files)
#       4 scn.all_dataset_names()
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/scene.py:133, in Scene.__init__(self, filenames, reader, filter_parameters, reader_kwargs)
#     130 if filenames:
#     131     filenames = convert_remote_files_to_fsspec(filenames, storage_options)
# --> 133 self._readers = self._create_reader_instances(filenames=filenames,
#     134                                               reader=reader,
#     135                                               reader_kwargs=cleaned_reader_kwargs)
#     136 self._datasets = DatasetDict()
#     137 self._wishlist = set()
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/scene.py:154, in Scene._create_reader_instances(self, filenames, reader, reader_kwargs)
#     149 def _create_reader_instances(self,
#     150                              filenames=None,
#     151                              reader=None,
#     152                              reader_kwargs=None):
#     153     """Find readers and return their instances."""
# --> 154     return load_readers(filenames=filenames,
#     155                         reader=reader,
#     156                         reader_kwargs=reader_kwargs)
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/readers/__init__.py:581, in load_readers(filenames, reader, reader_kwargs)
#     578         break
#     580 _check_remaining_files(remaining_filenames)
# --> 581 _check_reader_instances(reader_instances)
#     582 return reader_instances
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/satpy/readers/__init__.py:620, in _check_reader_instances(reader_instances)
#     618 def _check_reader_instances(reader_instances):
#     619     if not reader_instances:
# --> 620         raise ValueError("No supported files found")
#     621     if not any(list(r.available_dataset_ids) for r in reader_instances.values()):
#     622         raise ValueError("No dataset could be loaded. Either missing "
#     623                          "requirements (such as Epilog, Prolog) or none of the "
#     624                          "provided files match the filter parameters.")
#
# ValueError: No supported files found
