# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from mpl_toolkits.axes_grid1 import AxesGrid, make_axes_locatable
from glob import glob
import xarray as xr
import pandas as pd
import numpy as np1
from pyresample import geometry, create_area_def
from satpy import Scene
from cartopy.mpl.geoaxes import GeoAxes
import cmocean
import cmocean.cm as cmo
import matplotlib.cm as cm
from matplotlib import ticker

# %%
cfile = '/home/hboi-ouri/Projects/RS_Files/GCOOS Discharge/gom_discharge_1900_present.nc'

ds = xr.open_dataset(cfile)

ds
# Out:
# <xarray.Dataset>
# Dimensions:          (time: 43223, station: 61)
# Coordinates:
#   * time             (time) datetime64[ns] 1904-08-01 1904-08-02 ... 2022-12-02
#     gauge_latitude   (station) float64 ...
#     gauge_longitude  (station) float64 ...
# Dimensions without coordinates: station
# Data variables:
#     discharge        (time, station) float64 ...
#     station_id       (station) |S8 ...
#     river_name       (station) |S23 ...
#     end_date         (station) datetime64[ns] ...
#     start_date       (station) datetime64[ns] ...
#     mouth_latitude   (station) float64 ...
#     mouth_longitude  (station) float64 ...
# Attributes:
#     contact:                     Matthew Howard (mkhoward@tamu.edu), Chuan-Yu...
#     conventions:                 CF-1.6
#     featureType:                 timeSeries
#     institution:                 Texas A&M University
#     nco_openmp_thread_number:    1
#     processing_information_url:  http://stommel.tamu.edu/~baum/river.html
#     rivers:                      U.S. Gulf of Mexico Rivers
#     source:                      USGS and U.S. Army Corps of Engineers
#     source_url1:                 http://waterdata.usgs.gov/nwis
#     source_url2:                 http://www2.mvn.usace.army.mil/eng/edhd/dail...
#     title:                       Time-series discharge data for rivers emptyi...
#     history:                     created on : Tue Mar 15 18:31:45 2016, lates...

# %%
cfile = '/home/hboi-ouri/Projects/RS_Files/GCOOS Discharge/gom_discharge_1900_present.nc'

ds = xr.open_dataset(cfile)

dst = ds.discharge.transpose()

dst.coords
# 1904-08-01  2022-12-02

data = dst.isel(time='1904-08-01')
data.plot()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [64], in <cell line: 10>()
#       7 dst.coords
#       8 # 1904-08-01  2022-12-02
# ---> 10 data = dst.isel(time='1904-08-01')
#      11 data.plot()
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/xarray/core/dataarray.py:1390, in DataArray.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1387 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "isel")
#    1389 if any(is_fancy_indexer(idx) for idx in indexers.values()):
# -> 1390     ds = self._to_temp_dataset()._isel_fancy(
#    1391         indexers, drop=drop, missing_dims=missing_dims
#    1392     )
#    1393     return self._from_temp_dataset(ds)
#    1395 # Much faster algorithm for when all indexers are ints, slices, one-dimensional
#    1396 # lists, or zero or one-dimensional np.ndarray's
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/xarray/core/dataset.py:2475, in Dataset._isel_fancy(self, indexers, drop, missing_dims)
#    2471 var_indexers = {
#    2472     k: v for k, v in valid_indexers.items() if k in var.dims
#    2473 }
#    2474 if var_indexers:
# -> 2475     new_var = var.isel(indexers=var_indexers)
#    2476     # drop scalar coordinates
#    2477     # https://github.com/pydata/xarray/issues/6554
#    2478     if name in self.coords and drop and new_var.ndim == 0:
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/xarray/core/variable.py:1322, in Variable.isel(self, indexers, missing_dims, **indexers_kwargs)
#    1319 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    1321 key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1322 return self[key]
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/xarray/core/variable.py:870, in Variable.__getitem__(self, key)
#     857 """Return a new Variable object whose contents are consistent with
#     858 getting the provided key from the underlying data.
#     859
#    (...)
#     867 array `x.values` directly.
#     868 """
#     869 dims, indexer, new_order = self._broadcast_indexes(key)
# --> 870 data = as_indexable(self._data)[indexer]
#     871 if new_order:
#     872     data = np.moveaxis(data, range(len(new_order)), new_order)
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/xarray/core/indexing.py:1483, in PandasIndexingAdapter.__getitem__(self, indexer)
#    1480 if getattr(key, "ndim", 0) > 1:  # Return np-array if multidimensional
#    1481     return NumpyIndexingAdapter(np.asarray(self))[indexer]
# -> 1483 result = self.array[key]
#    1485 if isinstance(result, pd.Index):
#    1486     return type(self)(result, dtype=self.dtype)
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/pandas/core/indexes/base.py:5039, in Index.__getitem__(self, key)
#    5036 if is_integer(key) or is_float(key):
#    5037     # GH#44051 exclude bool, which would return a 2d ndarray
#    5038     key = com.cast_scalar_indexer(key, warn_float=True)
# -> 5039     return getitem(key)
#    5041 if isinstance(key, slice):
#    5042     # This case is separated from the conditional above to avoid
#    5043     # pessimization com.is_bool_indexer and ndim checks.
#    5044     result = getitem(key)
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/pandas/core/arrays/datetimelike.py:341, in DatetimeLikeArrayMixin.__getitem__(self, key)
#     333 """
#     334 This getitem defers to the underlying array, which by-definition can
#     335 only handle list-likes, slices, and integer scalars
#     336 """
#     337 # Use cast as we know we will get back a DatetimeLikeArray or DTScalar,
#     338 # but skip evaluating the Union at runtime for performance
#     339 # (see https://github.com/pandas-dev/pandas/pull/44624)
#     340 result = cast(
# --> 341     "Union[DatetimeLikeArrayT, DTScalarOrNaT]", super().__getitem__(key)
#     342 )
#     343 if lib.is_scalar(result):
#     344     return result
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/pandas/core/arrays/_mixins.py:272, in NDArrayBackedExtensionArray.__getitem__(self, key)
#     266 def __getitem__(
#     267     self: NDArrayBackedExtensionArrayT,
#     268     key: PositionalIndexer2D,
#     269 ) -> NDArrayBackedExtensionArrayT | Any:
#     270     if lib.is_integer(key):
#     271         # fast-path
# --> 272         result = self._ndarray[key]
#     273         if self.ndim == 1:
#     274             return self._box_func(result)
#
# IndexError: index -2064441600000000000 is out of bounds for axis 0 with size 43223

# %%
cfile = '/home/hboi-ouri/Projects/RS_Files/Task2/CruiseaCDOM/1GOM21SU_MODIS_L2_aCDOM.nc'

###  ds = airtemps



ds = xr.open_dataset(cfile)

data = ds.discharge
data




airtemps = xr.tutorial.open_dataset("air_temperature")

airtemps

air = airtemps.air - 273.15

# copy attributes to get nice figure labels and change Kelvin to Celsius

air.attrs = airtemps.air.attrs

air.attrs["units"] = "deg C"

air1d = air.isel(lat=10, lon=10)

air1d.plot()

data.plot.scatter()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [15], in <cell line: 5>()
#       1 cfile = '/home/hboi-ouri/Projects/RS_Files/Task2/CruiseaCDOM/1GOM21SU_MODIS_L2_aCDOM.nc'
#       3 ds = xr.open_dataset(cfile)
# ----> 5 data = ds.discharge('time')
#       7 data.plot.scatter()
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/xarray/core/common.py:278, in AttrAccessMixin.__getattr__(self, name)
#     276         with suppress(KeyError):
#     277             return source[name]
# --> 278 raise AttributeError(
#     279     f"{type(self).__name__!r} object has no attribute {name!r}"
#     280 )
#
# AttributeError: 'Dataset' object has no attribute 'discharge'

# %%
cfile = '/home/hboi-ouri/Projects/RS_Files/Task2/CruiseaCDOM/1GOM21SU_MODIS_L2_aCDOM.nc'

###  ds = airtemps



ds = xr.open_dataset(cfile)

discharge = ds.discharge
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [21], in <cell line: 9>()
#       3 ###  ds = airtemps
#       7 ds = xr.open_dataset(cfile)
# ----> 9 discharge = ds.discharge
#
# File ~/miniconda3/envs/Satpy/lib/python3.8/site-packages/xarray/core/common.py:278, in AttrAccessMixin.__getattr__(self, name)
#     276         with suppress(KeyError):
#     277             return source[name]
# --> 278 raise AttributeError(
#     279     f"{type(self).__name__!r} object has no attribute {name!r}"
#     280 )
#
# AttributeError: 'Dataset' object has no attribute 'discharge'

# %%
airtemps = xr.tutorial.open_dataset("air_temperature")

airtemps

airtemps.air
# Out:
# <xarray.DataArray 'air' (time: 2920, lat: 25, lon: 53)>
# [3869000 values with dtype=float32]
# Coordinates:
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
# Attributes:
#     long_name:     4xDaily Air temperature at sigma level 995
#     units:         degK
#     precision:     2
#     GRIB_id:       11
#     GRIB_name:     TMP
#     var_desc:      Air temperature
#     dataset:       NMC Reanalysis
#     level_desc:    Surface
#     statistic:     Individual Obs
#     parent_stat:   Other
#     actual_range:  [185.16 322.1 ]
